# %% [markdown]
# ## Testing Stable Diffusion in Keras CV

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import time, keras_cv, tensorflow as tf, matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = model.text_to_image('photograph of an astronaut riding a horse', batch_size=3)
# Out:
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
# 50/50 [==============================] - 47s 374ms/step
# ...

# %%
def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(images.shape[0]):
        plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis('off')
    plt.show()

plot_images(images)

# %%
images = model.text_to_image(
    'german shepherd dog, stylized, with focus on the eyes, '
    'old timey, high quality, highly detailed, '
    'concept art, with a dark background, '
    , batch_size=3
)
plot_images(images)
# Out:
# 50/50 [==============================] - 19s 376ms/step
